# %%
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df=pd.read_csv("C:\\Users\\lenovo\\Desktop\\Telecom.csv")
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.head(6)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sb
C_mat = df.corr()
fig = plt.figure(figsize=(15,15))
sb.heatmap(C_mat,vmax=.8,square=True)
plt.show()

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
data2=df.copy()

# %%
ax=sns.countplot(x="gender",data=data2)

# %%
ax=sns.countplot(x="SeniorCitizen",data=data2)

# %%
ax=sns.countplot(x="tenure",data=data2)

# %%
ax=sns.countplot(x="PhoneService",data=data2)

# %%
ax=sns.countplot(x="MultipleLines",data=data2)

# %%
ax=sns.countplot(x="InternetService",data=data2)

# %%
ax=sns.countplot(x="OnlineSecurity",data=data2)

# %%
ax=sns.countplot(x="OnlineBackup",data=data2)

# %%
ax=sns.countplot(x="DeviceProtection",data=data2)

# %%
ax=sns.countplot(x="TechSupport",data=data2)

# %%
ax=sns.countplot(x="StreamingTV",data=data2)

# %%
ax=sns.countplot(x="StreamingMovies",data=data2)

# %%
ax=sns.countplot(x="Contract",data=data2)

# %%
ax=sns.countplot(x="PaperlessBilling",data=data2)

# %%
ax=sns.countplot(x="PaymentMethod",data=data2)

# %%
ax=sns.countplot(x="MonthlyCharges",data=data2)

# %%
ax=sns.countplot(x="TotalCharges",data=data2)

# %%
ax=sns.countplot(x="Churn",data=data2)

# %%
dist = (data2['Churn'])
distset = set(dist)
dd=list(distset)
dictOfWords = {dd[i] : i for i in range(0,len(dd))}
data2['churn'] = data2['Churn'].map(dictOfWords)

# %%
dictOfWords
# Out:
# {'No': 0, 'Yes': 1}

# %%
data2
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
sns.relplot(
    data=data2, x="gender",y="Churn",kind="line",
)

# %%
data2.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn', 'churn'],
#       dtype='object')

# %%
sns.relplot(
    data=data2, x="SeniorCitizen",y="Churn",kind="line",
)

# %%
 sns.relplot(
    data=data2, x="Partner",y="Churn",kind="line",
)

# %%
sns.relplot(
    data=data2, x="Dependents",y="Churn",kind="line",
)

# %%
sns.relplot(
    data=data2, x="tenure",y="Churn",kind="line",
)

# %%
sns.relplot(
    data=data2, x="PhoneService",y="Churn",kind="line",
)

# %%
sns.relplot(
    data=data2, x="InternetService",y="Churn",kind="line",
)

# %%
sns.relplot(
    data=data2, x="OnlineSecurity",y="Churn",kind="line",
)

# %%
sns.relplot(
    data=data2, x="OnlineBackup",y="Churn",kind="line",
)

# %%
sns.relplot(
    data=data2, x="DeviceProtection",y="Churn",kind="line",
)

# %%
sns.relplot(
    data=data2, x="TechSupport",y="Churn",kind="line",
)

# %%
sns.relplot(
    data=data2, x="StreamingTV",y="Churn",kind="line",
)

# %%
sns.relplot(
    data=data2, x="StreamingMovies",y="Churn",kind="line",
)

# %%
sns.relplot(
    data=data2, x="Contract",y="Churn",kind="line",
)

# %%
sns.relplot(
    data=data2, x="PaperlessBilling",y="Churn",kind="line",
)

# %%
sns.relplot(
    data=data2, x="PaymentMethod",y="Churn",kind="line",
)

# %%
sns.relplot(
    data=data2, x="MonthlyCharges",y="Churn",kind="line",
)

# %%
sns.relplot(
    data=data2, x="TotalCharges",y="Churn",kind="line",
)

# %%
data2.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn', 'churn'],
#       dtype='object')

# %%
data2=df

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
data2['tenure'] = data2['tenure'].astype(int)

# %%
data2['MonthlyCharges']=data2['MonthlyCharges'].astype(int)

# %%
data2.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
dist=(data2['gender'])
distset=set(dist)
dd=list(distset)
dictOfWords = {dd[i] : i for i in range(0,len(dd))}
data2['gender']=data2['gender'].map(dictOfWords)

# %%
dist=(data2['Partner'])
distset=set(dist)
dd=list(distset)
dictOfWords = {dd[i] : i for i in range(0,len(dd))}
data2['Partner']=data2['Partner'].map(dictOfWords)

# %%
dist=(data2['Dependents'])
distset=set(dist)
dd=list(distset)
dictOfWords = {dd[i] : i for i in range(0,len(dd))}
data2['Dependents']=data2['Dependents'].map(dictOfWords)

# %%
dist=(data2['PhoneService'])
distset=set(dist)
dd=list(distset)
dictOfWords = {dd[i] : i for i in range(0,len(dd))}
data2['PhoneService']=data2['PhoneService'].map(dictOfWords)

# %%
dist=(data2['MultipleLines'])
distset=set(dist)
dd=list(distset)
dictOfWords = {dd[i] : i for i in range(0,len(dd))}
data2['MultipleLines']=data2['MultipleLines'].map(dictOfWords)

# %%
dist=(data2['InternetService'])
distset=set(dist)
dd=list(distset)
dictOfWords = {dd[i] : i for i in range(0,len(dd))}
data2['InternetService']=data2['InternetService'].map(dictOfWords)

# %%
dist=(data2['OnlineSecurity'])
distset=set(dist)
dd=list(distset)
dictOfWords = {dd[i] : i for i in range(0,len(dd))}
data2['OnlineSecurity']=data2['OnlineSecurity'].map(dictOfWords)

# %%
dist=(data2['OnlineBackup'])
distset=set(dist)
dd=list(distset)
dictOfWords = {dd[i] : i for i in range(0,len(dd))}
data2['OnlineBackup']=data2['OnlineBackup'].map(dictOfWords)

# %%
dist=(data2['DeviceProtection'])
distset=set(dist)
dd=list(distset)
dictOfWords = {dd[i] : i for i in range(0,len(dd))}
data2['DeviceProtection']=data2['DeviceProtection'].map(dictOfWords)

# %%
dist=(data2['TechSupport'])
distset=set(dist)
dd=list(distset)
dictOfWords = {dd[i] : i for i in range(0,len(dd))}
data2['TechSupport']=data2['TechSupport'].map(dictOfWords)

# %%
dist=(data2['StreamingTV'])
distset=set(dist)
dd=list(distset)
dictOfWords = {dd[i] : i for i in range(0,len(dd))}
data2['StreamingTV']=data2['StreamingTV'].map(dictOfWords)

# %%
dist=(data2['Contract'])
distset=set(dist)
dd=list(distset)
dictOfWords = {dd[i] : i for i in range(0,len(dd))}
data2['Contract']=data2['Contract'].map(dictOfWords)

# %%
dist=(data2['PaperlessBilling'])
distset=set(dist)
dd=list(distset)
dictOfWords = {dd[i] : i for i in range(0,len(dd))}
data2['PaperlessBilling']=data2['PaperlessBilling'].map(dictOfWords)

# %%
dist=(data2['PaymentMethod'])
distset=set(dist)
dd=list(distset)
dictOfWords = {dd[i] : i for i in range(0,len(dd))}
data2['PaymentMethod']=data2['PaymentMethod'].map(dictOfWords)

# %%
dist=(data2['MonthlyCharges'])
distset=set(dist)
dd=list(distset)
dictOfWords = {dd[i] : i for i in range(0,len(dd))}
data2['MonthlyCharges']=data2['MonthlyCharges'].map(dictOfWords)

# %%
dist=(data2['TotalCharges'])
distset=set(dist)
dd=list(distset)
dictOfWords = {dd[i] : i for i in range(0,len(dd))}
data2['TotalCharges']=data2['TotalCharges'].map(dictOfWords)

# %%
dist=(data2['StreamingMovies'])
distset=set(dist)
dd=list(distset)
dictOfWords = {dd[i] : i for i in range(0,len(dd))}
data2['StreamingMovies']=data2['StreamingMovies'].map(dictOfWords)

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   int64
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   int64
#  4   Dependents        7043 non-null   int64
#  5   tenure            7043 non-null   int32
#  6   PhoneService      7043 non-null   int64
#  7   MultipleLines     7043 non-null   int64
#  8   InternetService   7043 non-null   int64
#  9   OnlineSecurity    7043 non-null   int64
#  10  OnlineBackup      7043 non-null   int64
#  11  DeviceProtection  7043 non-null   int64
#  12  TechSupport       7043 non-null   int64
#  13  StreamingTV       7043 non-null   int64
#  14  StreamingMovies   7043 non-null   int64
#  15  Contract          7043 non-null   int64
# ...

# %%
dist=(data2['Churn'])
distset=set(dist)
dd=list(distset)
dictOfWords = {dd[i] : i for i in range(0,len(dd))}
data2['Churn']=data2['Churn'].map(dictOfWords)

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   int64
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   int64
#  4   Dependents        7043 non-null   int64
#  5   tenure            7043 non-null   int32
#  6   PhoneService      7043 non-null   int64
#  7   MultipleLines     7043 non-null   int64
#  8   InternetService   7043 non-null   int64
#  9   OnlineSecurity    7043 non-null   int64
#  10  OnlineBackup      7043 non-null   int64
#  11  DeviceProtection  7043 non-null   int64
#  12  TechSupport       7043 non-null   int64
#  13  StreamingTV       7043 non-null   int64
#  14  StreamingMovies   7043 non-null   int64
#  15  Contract          7043 non-null   int64
# ...

# %%
data2.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
data2.dropna(inplace=True)

# %%
features = data2[['Dependents', 'tenure', 'PhoneService', 'Contract', 'MonthlyCharges' , 'TotalCharges']]
labels=data2['Churn']

# %%
data2.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  7590-VHVEG       1              0        1           0       1
# 1  5575-GNVDE       0              0        0           0      34
# 2  3668-QPYBK       0              0        0           0       2
# 3  7795-CFOCW       0              0        0           0      45
# 4  9237-HQITU       1              0        0           0       2
#
#    PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 0             0              2                2               0  ...
# 1             1              0                2               2  ...
# 2             1              0                2               2  ...
# 3             0              2                2               2  ...
# 4             1              0                1               0  ...
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         2
# ...

# %%
data2.dropna(inplace=True)

# %%
#Splitting into testing and training data

from sklearn.model_selection import train_test_split
Xtrain,Xtest,Ytrain,Ytest = train_test_split(features,labels,test_size=0.2,random_state=2)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report
from sklearn import metrics
from sklearn import tree

# %%
from sklearn.tree import DecisionTreeClassifier
DecisionTree = DecisionTreeClassifier(criterion="entropy",random_state=2,max_depth=5)
DecisionTree.fit(Xtrain,Ytrain)
predicted_values = DecisionTree.predict(Xtest)
x=metrics.accuracy_score(Ytest,predicted_values)
print("DecisionTrees's Accuaracy is: ",x)
print(classification_report(Ytest,predicted_values))
# Out:
# DecisionTrees's Accuaracy is:  0.7998580553584103
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87      1061
#            1       0.63      0.46      0.53       348
#
#     accuracy                           0.80      1409
#    macro avg       0.73      0.68      0.70      1409
# weighted avg       0.79      0.80      0.79      1409

# %%
from sklearn.tree import DecisionTreeClassifier
dtree_model = DecisionTreeClassifier(max_depth = 3).fit(Xtrain, Ytrain)
dtree_predictions = dtree_model.predict(Xtest)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Ytest, dtree_predictions)
cm
# Out:
# array([[1000,   61],
#        [ 226,  122]], dtype=int64)

# %%
dtree_model.predict(Xtest)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
accuracy = dtree_model.score(Xtest, Ytest)
accuracy
# Out:
# 0.7963094393186657

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error


mse=mean_squared_error(Ytest,dtree_predictions)
print('MSE =',mse)
mae=mean_absolute_error(Ytest,dtree_predictions)
print('MAE =',mae)
rmse=np.sqrt(mse)
print('RMSE =',rmse)
# Out:
# MSE = 0.2036905606813343
# MAE = 0.2036905606813343
# RMSE = 0.45132090654138135

# %%
from sklearn import metrics
r2=metrics.r2_score(Ytest,dtree_predictions)
r2
# Out:
# -0.09521217242462643

# %%
from sklearn.model_selection import learning_curve,ShuffleSplit,validation_curve
train_sizes, train_scores, test_scores = learning_curve(
    estimator=dtree_model,
     X=features,
    y=labels,
    cv=5,
    scoring="neg_root_mean_squared_error",
    train_sizes = [1, 75, 165, 270, 331]
)

train_mean = -train_scores.mean(axis=1)
test_mean = -test_scores.mean(axis=1)

plt.subplots(figsize=(10,4))
plt.plot(train_sizes, train_mean, label="train")
plt.plot(train_sizes, test_mean, label="validation")

plt.title("Learning Curve of Decision tree regressor")
plt.xlabel("Training Set Size")
plt.ylabel("RMSE")
plt.legend(loc="best")

plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
NavieBayes = GaussianNB()
NavieBayes.fit(Xtrain,Ytrain)
predicted_values = NavieBayes.predict(Xtest)
x=metrics.accuracy_score(Ytest,predicted_values)
print("Navie Bayes's Accuarcy si: ",x*100)
print(classification_report(Ytest,predicted_values))
# Out:
# Navie Bayes's Accuarcy si:  74.23704755145494
#               precision    recall  f1-score   support
#
#            0       0.86      0.79      0.82      1061
#            1       0.48      0.60      0.53       348
#
#     accuracy                           0.74      1409
#    macro avg       0.67      0.69      0.68      1409
# weighted avg       0.76      0.74      0.75      1409

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB().fit(Xtrain, Ytrain)
gnb_predictions = gnb.predict(Xtest)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Ytest, dtree_predictions)
cm
# Out:
# array([[1000,   61],
#        [ 226,  122]], dtype=int64)

# %%
gnb.predict(Xtest)
# Out:
# array([0, 0, 0, ..., 0, 0, 1], dtype=int64)

# %%
accuracy = gnb.score(Xtest, Ytest)
accuracy
# Out:
# 0.7423704755145494

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error


mse=mean_squared_error(Ytest,dtree_predictions)
print('MSE =',mse)
mae=mean_absolute_error(Ytest,dtree_predictions)
print('MAE =',mae)
rmse=np.sqrt(mse)
print('RMSE =',rmse)
# Out:
# MSE = 0.2036905606813343
# MAE = 0.2036905606813343
# RMSE = 0.45132090654138135

# %%
from sklearn import metrics
r2=metrics.r2_score(Ytest,gnb_predictions)
r2
# Out:
# -0.38523351425135677

# %%
from sklearn.model_selection import learning_curve,ShuffleSplit,validation_curve
train_sizes, train_scores, test_scores = learning_curve(
    estimator=dtree_model,
     X=features,
    y=labels,
    cv=5,
    scoring="neg_root_mean_squared_error",
    train_sizes = [1, 75, 165, 270, 331]
)

train_mean = -train_scores.mean(axis=1)
test_mean = -test_scores.mean(axis=1)

plt.subplots(figsize=(10,4))
plt.plot(train_sizes, train_mean, label="train")
plt.plot(train_sizes, test_mean, label="validation")

plt.title("Learning Curve of GAUSSIONNB")
plt.xlabel("Training Set Size")
plt.ylabel("RMSE")
plt.legend(loc="best")

plt.show()

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import MinMaxScaler
norm = MinMaxScaler().fit(Xtrain)
X_train_norm = norm.transform(Xtrain)
X_test_norm = norm.transform(Xtrain)
X_test_norm = norm.transform(Xtest)
SVM =SVC(kernel='poly',degree=3,C=1)
SVM.fit(X_train_norm,Ytrain)
predicted_values = SVM.predict(X_test_norm)
print("SVM's Acuuracy is: ",x*100)
print(classification_report(Ytest,predicted_values))
# Out:
# SVM's Acuuracy is:  74.23704755145494
#               precision    recall  f1-score   support
#
#            0       0.83      0.93      0.88      1061
#            1       0.66      0.43      0.52       348
#
#     accuracy                           0.80      1409
#    macro avg       0.74      0.68      0.70      1409
# weighted avg       0.79      0.80      0.79      1409

# %%
from sklearn.svm import SVC
svc = SVC().fit(Xtrain, Ytrain)
svc_prediction = svc.predict(Xtest)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Ytest,svc_prediction)
cm
# Out:
# array([[1061,    0],
#        [ 348,    0]], dtype=int64)

# %%
svc.predict(Xtest)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
accuracy = svc.score(Xtest, Ytest)
accuracy
# Out:
# 0.7530163236337828

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error


mse=mean_squared_error(Ytest,dtree_predictions)
print('MSE =',mse)
mae=mean_absolute_error(Ytest,dtree_predictions)
print('MAE =',mae)
rmse=np.sqrt(mse)
print('RMSE =',rmse)
# Out:
# MSE = 0.2036905606813343
# MAE = 0.2036905606813343
# RMSE = 0.45132090654138135

# %%
from sklearn import metrics
r2=metrics.r2_score(Ytest,gnb_predictions)
r2
# Out:
# -0.38523351425135677

# %%
from sklearn.model_selection import learning_curve,ShuffleSplit,validation_curve
train_sizes, train_scores, test_scores = learning_curve(
    estimator=dtree_model,
     X=features,
    y=labels,
    cv=5,
    scoring="neg_root_mean_squared_error",
    train_sizes = [1, 75, 165, 270, 331]
)

train_mean = -train_scores.mean(axis=1)
test_mean = -test_scores.mean(axis=1)

plt.subplots(figsize=(10,4))
plt.plot(train_sizes, train_mean, label="train")
plt.plot(train_sizes, test_mean, label="validation")

plt.title("Learning Curve of SVC")
plt.xlabel("Training Set Size")
plt.ylabel("RMSE")
plt.legend(loc="best")

plt.show()

# %%
from sklearn.linear_model import LogisticRegression
LogReg = LogisticRegression(random_state=2)
LogReg.fit(Xtrain,Ytrain)
predicred_values = LogReg.predict(Xtest)
x=metrics.accuracy_score(Ytest,predicted_values)
print("Logistic Regression's Accuracy is: ",x*100)
print(classification_report(Ytest,predicted_values))
# Out:
# Logistic Regression's Accuracy is:  80.34066713981547
#               precision    recall  f1-score   support
#
#            0       0.83      0.93      0.88      1061
#            1       0.66      0.43      0.52       348
#
#     accuracy                           0.80      1409
#    macro avg       0.74      0.68      0.70      1409
# weighted avg       0.79      0.80      0.79      1409

# %%
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression().fit(Xtrain, Ytrain)
LR_Predict = LR.predict(Xtest)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Ytest,LR_Predict)
cm
# Out:
# array([[951, 110],
#        [186, 162]], dtype=int64)

# %%
LR.predict(Xtest)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
accuracy = LR.score(Xtest, Ytest)
accuracy
# Out:
# 0.7899219304471257

# %%
from sklearn.model_selection import learning_curve,ShuffleSplit,validation_curve
train_sizes, train_scores, test_scores = learning_curve(
    estimator=dtree_model,
     X=features,
    y=labels,
    cv=5,
    scoring="neg_root_mean_squared_error",
    train_sizes = [1, 75, 165, 270, 331]
)

train_mean = -train_scores.mean(axis=1)
test_mean = -test_scores.mean(axis=1)

plt.subplots(figsize=(10,4))
plt.plot(train_sizes, train_mean, label="train")
plt.plot(train_sizes, test_mean, label="validation")

plt.title("Learning Curve of LOGISTIC REGRESSION")
plt.xlabel("Training Set Size")
plt.ylabel("RMSE")
plt.legend(loc="best")

plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
RF = RandomForestClassifier(n_estimators=20,random_state=0)
RF.fit(Xtrain,Ytrain)
predicted_values = RF.predict(Xtest)
x=metrics.accuracy_score(Ytest,predicted_values)
print("RF's Accuracy is: ",x*100)
print(classification_report(Ytest,predicted_values))
# Out:
# RF's Accuracy is:  77.57274662881476
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.86      1061
#            1       0.56      0.45      0.50       348
#
#     accuracy                           0.78      1409
#    macro avg       0.69      0.67      0.68      1409
# weighted avg       0.76      0.78      0.77      1409

# %%
from sklearn.ensemble import RandomForestClassifier
RF = RandomForestClassifier().fit(Xtrain, Ytrain)
RF_Predict = RF.predict(Xtest)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Ytest,RF_Predict)
cm
# Out:
# array([[931, 130],
#        [184, 164]], dtype=int64)

# %%
RF.predict(Xtest)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
accuracy = RF.score(Xtest, Ytest)
accuracy
# Out:
# 0.7771469127040455

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error


mse=mean_squared_error(Ytest,dtree_predictions)
print('MSE =',mse)
mae=mean_absolute_error(Ytest,dtree_predictions)
print('MAE =',mae)
rmse=np.sqrt(mse)
print('RMSE =',rmse)
# Out:
# MSE = 0.2036905606813343
# MAE = 0.2036905606813343
# RMSE = 0.45132090654138135

# %%
from sklearn import metrics
r2=metrics.r2_score(Ytest,RF_Predict)
r2
# Out:
# -0.19824607017885953

# %%
from sklearn.model_selection import learning_curve,ShuffleSplit,validation_curve
train_sizes, train_scores, test_scores = learning_curve(
    estimator=dtree_model,
     X=features,
    y=labels,
    cv=5,
    scoring="neg_root_mean_squared_error",
    train_sizes = [1, 75, 165, 270, 331]
)

train_mean = -train_scores.mean(axis=1)
test_mean = -test_scores.mean(axis=1)

plt.subplots(figsize=(10,4))
plt.plot(train_sizes, train_mean, label="train")
plt.plot(train_sizes, test_mean, label="validation")

plt.title("Learning Curve of RANDOM FOREST CLASSIFIER")
plt.xlabel("Training Set Size")
plt.ylabel("RMSE")
plt.legend(loc="best")

plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(Xtrain, Ytrain)
predicted_values = knn.predict(Xtest)
x = metrics.accuracy_score(Ytest, predicted_values)
print("K-NN's Accuracy is:",x*100)
print(classification_report(Ytest, predicted_values))
# Out:
# K-NN's Accuracy is: 73.81121362668559
#               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83      1061
#            1       0.46      0.39      0.42       348
#
#     accuracy                           0.74      1409
#    macro avg       0.64      0.62      0.63      1409
# weighted avg       0.72      0.74      0.73      1409
# C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 7).fit(Xtrain, Ytrain)
knn_predictions = knn.predict(Xtest)
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Ytest, knn_predictions)
cm
# Out:
# array([[924, 137],
#        [226, 122]], dtype=int64)

# %%
knn.predict(Xtest)
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# array([0, 1, 0, ..., 0, 0, 0], dtype=int64)

# %%
accuracy = knn.score(Xtest, Ytest)
accuracy
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# 0.7423704755145494

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error


mse=mean_squared_error(Ytest,knn_predictions)
print('MSE =',mse)
mae=mean_absolute_error(Ytest,knn_predictions)
print('MAE =',mae)
rmse=np.sqrt(mse)
print('RMSE =',rmse)
# Out:
# MSE = 0.2576295244854507
# MAE = 0.2576295244854507
# RMSE = 0.5075721864774021

# %%
from sklearn import metrics
r2=metrics.r2_score(Ytest,knn_predictions)
r2
# Out:
# -0.38523351425135677

# %%
from sklearn.model_selection import learning_curve,ShuffleSplit,validation_curve
train_sizes, train_scores, test_scores = learning_curve(
    estimator=dtree_model,
     X=features,
    y=labels,
    cv=5,
    scoring="neg_root_mean_squared_error",
    train_sizes = [1, 75, 165, 270, 331]
)

train_mean = -train_scores.mean(axis=1)
test_mean = -test_scores.mean(axis=1)

plt.subplots(figsize=(10,4))
plt.plot(train_sizes, train_mean, label="train")
plt.plot(train_sizes, test_mean, label="validation")

plt.title("Learning Curve of KNN")
plt.xlabel("Training Set Size")
plt.ylabel("RMSE")
plt.legend(loc="best")

plt.show()

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report
mlp = MLPClassifier(hidden_layer_sizes=(100, 50), activation='relu', solver='adam', random_state=0)
mlp.fit(Xtrain, Ytrain)
predicted_values = mlp.predict(Xtest)
accuracy = accuracy_score(Ytest, predicted_values)
print("MLP's Accuracy is:", accuracy*100)
print(classification_report(Ytest, predicted_values))
# Out:
# MLP's Accuracy is: 75.8694109297374
#               precision    recall  f1-score   support
#
#            0       0.76      1.00      0.86      1061
#            1       0.75      0.03      0.07       348
#
#     accuracy                           0.76      1409
#    macro avg       0.75      0.52      0.46      1409
# weighted avg       0.76      0.76      0.66      1409

# %%
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier().fit(Xtrain, Ytrain)
mlp_predictions = mlp.predict(Xtest)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Ytest, mlp_predictions)
cm
# Out:
# array([[983,  78],
#        [244, 104]], dtype=int64)

# %%
mlp.predict(Xtest)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
accuracy = mlp.score(Xtest, Ytest)
accuracy
# Out:
# 0.7714691270404542

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error


mse=mean_squared_error(Ytest,knn_predictions)
print('MSE =',mse)
mae=mean_absolute_error(Ytest,knn_predictions)
print('MAE =',mae)
rmse=np.sqrt(mse)
print('RMSE =',rmse)
# Out:
# MSE = 0.2576295244854507
# MAE = 0.2576295244854507
# RMSE = 0.5075721864774021

# %%
from sklearn import metrics
r2=metrics.r2_score(Ytest,mlp_predictions)
r2
# Out:
# -0.22877463247641017

# %%
from sklearn.model_selection import learning_curve,ShuffleSplit,validation_curve
train_sizes, train_scores, test_scores = learning_curve(
    estimator=dtree_model,
     X=features,
    y=labels,
    cv=5,
    scoring="neg_root_mean_squared_error",
    train_sizes = [1, 75, 165, 270, 331]
)

train_mean = -train_scores.mean(axis=1)
test_mean = -test_scores.mean(axis=1)

plt.subplots(figsize=(10,4))
plt.plot(train_sizes, train_mean, label="train")
plt.plot(train_sizes, test_mean, label="validation")

plt.title("Learning Curve of MLP CLASSIFIER")
plt.xlabel("Training Set Size")
plt.ylabel("RMSE")
plt.legend(loc="best")

plt.show()

# %%
# !pip install -U gradio
# Out:
# ...
#   Using cached gradio-4.19.2-py3-none-any.whl (16.9 MB)
# ...
#   Using cached altair-5.2.0-py3-none-any.whl (996 kB)
# ...
#   Using cached httpx-0.27.0-py3-none-any.whl (75 kB)
# ...
#   Using cached gradio_client-0.10.1-py3-none-any.whl (307 kB)
# ...
#   Using cached starlette-0.21.0-py3-none-any.whl (64 kB)
# ...
#   Using cached fastapi-0.110.0-py3-none-any.whl (92 kB)
# ...
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.23.1
#     Uninstalling httpx-0.23.1:
#       Successfully uninstalled httpx-0.23.1
#   Attempting uninstall: fastapi
#     Found existing installation: fastapi 0.87.0
#     Uninstalling fastapi-0.87.0:
#       Successfully uninstalled fastapi-0.87.0
#   Attempting uninstall: gradio
#     Found existing installation: gradio 3.11.0
#     Uninstalling gradio-3.11.0:
#       Successfully uninstalled gradio-3.11.0
# ...

# %%
import gradio as gr

# %%
import gradio as gr
from gradio import components

def churn(Dependents, tenure, PhoneService, Contract, MonthlyCharges, TotalCharges):
    x = np.array([Dependents, tenure, PhoneService, Contract, MonthlyCharges, TotalCharges])
    prediction = LR.predict(x.reshape(1, -1))
    return prediction

outputs = components.Textbox()
app = gr.Interface(fn=churn, inputs=['number', 'number', 'number', 'number', 'number', 'number'], outputs=outputs, description="Customer Churn Prediction Model")

# %%
app.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7866
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7866/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import time

max_retries = 3
retries = 0
connected = False

while retries < max_retries and not connected:
    try:
        # Attempt to establish the connection here
        # Your connection code goes here
        connected = True  # Set connected to True if the connection is successful
    except TimeoutError:
        print("Connection attempt timed out. Retrying...")
        retries += 1
        time.sleep(1)  # Wait for a short time before retrying

if not connected:
    print("Failed to establish connection after {} retries.".format(max_retries))

# %%
app.launch(share=True)
# Out:
# Rerunning server... use `close()` to stop if you need to change `launch()` parameters.
# ----
# Running on public URL: https://864a6c1e116feaceb5.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://864a6c1e116feaceb5.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# ...
